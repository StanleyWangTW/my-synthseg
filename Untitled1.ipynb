# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
img = nib.load("seg.nii.gz").get_fdata()
np.unique(img)
# Out:
# array([  0.,   2.,   3.,   4.,   5.,   7.,   8.,  10.,  11.,  12.,  13.,
#         14.,  15.,  16.,  17.,  18.,  24.,  26.,  28.,  30.,  31.,  41.,
#         42.,  43.,  44.,  46.,  47.,  49.,  50.,  51.,  52.,  53.,  54.,
#         58.,  60.,  62.,  63.,  77.,  80.,  85., 165., 258., 259.])

# %%
np.unique(img).shape
# Out:
# (43,)

# %%
plt.figure()
plt.imshow(np.rot90(img[120, :, :]), cmap="gist_ncar")
plt.show()

# %%
# img[img == 24] = 0
img[img == 165] = 0
img[img == 258] = 0
img[img == 259] = 0
plt.figure()
plt.imshow(np.rot90(img[120, :, :]), cmap="gist_ncar")
plt.show()
